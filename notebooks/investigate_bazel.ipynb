# %%
import networkx
import pandas
from networkx.drawing import nx_agraph

# %%
# %matplotlib inline

# %%
g = networkx.read_gml("/home/mchristen/devel/toolbox/my.gml")

# %%
nodes = g.nodes(data=True)

# %%
df_nodes = pandas.DataFrame(
    [n[1] for n in nodes],
    columns=[
        "node_name",
        "node_class",
        "num_parents",
        "num_ancestors",
        "num_duration_ancestors",
        "num_children",
        "num_descendants",
        "num_source_descendants",
        "pagerank",
        "hubs_metric",
        "authorities_metric",
        "node_duration_s",
        "group_duration_s",
        "expected_duration_s",
        "node_probability_cache_hit",
        "group_probability_cache_hit",
    ],
)
df_nodes.set_index("node_name", inplace=True)

# %%
df_nodes
# Out:
#                                                                     node_class  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5     npm_package_store_internal
# //:.aspect_rules_js/node_modules/prettier@3.2.5...  npm_package_store_internal
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                   filegroup
# //:.aspect_rules_js/node_modules/prettier@3.2.5...  npm_package_store_internal
# //:create_venv                                                           _venv
# ...                                                                        ...
# //third_party/bazel/proto:build_event_stream_py...                     unknown
# //utils:bep_reader.venv                                           py_venv_rule
# //utils:graph_algorithms.py                                        source_file
# //utils:graph_algorithms_test                                          py_test
# //utils:graph_algorithms_test.py                                   source_file
#
#                                                     num_parents  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5               3
# //:.aspect_rules_js/node_modules/prettier@3.2.5...            1
# //:.aspect_rules_js/node_modules/prettier@3.2.5...            1
# //:.aspect_rules_js/node_modules/prettier@3.2.5...            0
# //:create_venv                                                0
# ...                                                         ...
# //third_party/bazel/proto:build_event_stream_py...            2
# //utils:bep_reader.venv                                       0
# //utils:graph_algorithms.py                                   1
# //utils:graph_algorithms_test                                 0
# //utils:graph_algorithms_test.py                              1
#
#                                                     num_ancestors  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                 6
# //:.aspect_rules_js/node_modules/prettier@3.2.5...              7
# //:.aspect_rules_js/node_modules/prettier@3.2.5...              2
# //:.aspect_rules_js/node_modules/prettier@3.2.5...              0
# //:create_venv                                                  0
# ...                                                           ...
# //third_party/bazel/proto:build_event_stream_py...              4
# //utils:bep_reader.venv                                         0
# //utils:graph_algorithms.py                                     4
# //utils:graph_algorithms_test                                   0
# //utils:graph_algorithms_test.py                                1
#
#                                                     num_duration_ancestors  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                          0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                       0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                       0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                       0
# //:create_venv                                                           0
# ...                                                                    ...
# //third_party/bazel/proto:build_event_stream_py...                       0
# //utils:bep_reader.venv                                                  0
# //utils:graph_algorithms.py                                              1
# //utils:graph_algorithms_test                                            0
# //utils:graph_algorithms_test.py                                         1
#
#                                                     num_children  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                1
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             1
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0
# //:create_venv                                                 1
# ...                                                          ...
# //third_party/bazel/proto:build_event_stream_py...             0
# //utils:bep_reader.venv                                        2
# //utils:graph_algorithms.py                                    0
# //utils:graph_algorithms_test                                  4
# //utils:graph_algorithms_test.py                               0
#
#                                                     num_descendants  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                   1
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                2
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                0
# //:create_venv                                                    1
# ...                                                             ...
# //third_party/bazel/proto:build_event_stream_py...                0
# //utils:bep_reader.venv                                           3
# //utils:graph_algorithms.py                                       0
# //utils:graph_algorithms_test                                     5
# //utils:graph_algorithms_test.py                                  0
#
#                                                     num_source_descendants  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                          0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                       0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                       0
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                       0
# //:create_venv                                                           1
# ...                                                                    ...
# //third_party/bazel/proto:build_event_stream_py...                       0
# //utils:bep_reader.venv                                                  1
# //utils:graph_algorithms.py                                              0
# //utils:graph_algorithms_test                                            4
# //utils:graph_algorithms_test.py                                         0
#
#                                                     pagerank   hubs_metric  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5     0.006603 -3.455979e-20
# //:.aspect_rules_js/node_modules/prettier@3.2.5...  0.006792  0.000000e+00
# //:.aspect_rules_js/node_modules/prettier@3.2.5...  0.002608  0.000000e+00
# //:.aspect_rules_js/node_modules/prettier@3.2.5...  0.001179  0.000000e+00
# //:create_venv                                      0.001179  7.573706e-18
# ...                                                      ...           ...
# //third_party/bazel/proto:build_event_stream_py...  0.001985  0.000000e+00
# //utils:bep_reader.venv                             0.001179  6.277635e-03
# //utils:graph_algorithms.py                         0.002611  0.000000e+00
# //utils:graph_algorithms_test                       0.001179  6.229455e-02
# //utils:graph_algorithms_test.py                    0.001430  0.000000e+00
#
#                                                     authorities_metric  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5           0.000000e+00
# //:.aspect_rules_js/node_modules/prettier@3.2.5...       -1.203359e-19
# //:.aspect_rules_js/node_modules/prettier@3.2.5...       -3.859016e-19
# //:.aspect_rules_js/node_modules/prettier@3.2.5...       -4.511004e-18
# //:create_venv                                           -2.201309e-18
# ...                                                                ...
# //third_party/bazel/proto:build_event_stream_py...        2.890616e-03
# //utils:bep_reader.venv                                   5.937166e-18
# //utils:graph_algorithms.py                              -1.363460e-20
# //utils:graph_algorithms_test                            -7.205433e-19
# //utils:graph_algorithms_test.py                          1.336722e-02
#
#                                                     node_duration_s  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5               0.000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...            0.000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...            0.000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...            0.000
# //:create_venv                                                0.000
# ...                                                             ...
# //third_party/bazel/proto:build_event_stream_py...            0.000
# //utils:bep_reader.venv                                       0.000
# //utils:graph_algorithms.py                                   0.000
# //utils:graph_algorithms_test                                 0.691
# //utils:graph_algorithms_test.py                              0.000
#
#                                                     group_duration_s  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                0.000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0.000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0.000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0.000
# //:create_venv                                                 0.000
# ...                                                              ...
# //third_party/bazel/proto:build_event_stream_py...             0.000
# //utils:bep_reader.venv                                        0.000
# //utils:graph_algorithms.py                                    0.691
# //utils:graph_algorithms_test                                  0.691
# //utils:graph_algorithms_test.py                               0.691
#
#                                                     expected_duration_s  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                0.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...             0.000000
# //:create_venv                                                 0.000000
# ...                                                                 ...
# //third_party/bazel/proto:build_event_stream_py...             0.000000
# //utils:bep_reader.venv                                        0.000000
# //utils:graph_algorithms.py                                    0.039648
# //utils:graph_algorithms_test                                  0.096643
# //utils:graph_algorithms_test.py                               0.022656
#
#                                                     node_probability_cache_hit  \
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                       1.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                    1.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                    1.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                    1.000000
# //:create_venv                                                        1.000000
# ...                                                                        ...
# //third_party/bazel/proto:build_event_stream_py...                    1.000000
# //utils:bep_reader.venv                                               1.000000
# //utils:graph_algorithms.py                                           0.942623
# //utils:graph_algorithms_test                                         1.000000
# //utils:graph_algorithms_test.py                                      0.967213
#
#                                                     group_probability_cache_hit
# node_name
# //:.aspect_rules_js/node_modules/prettier@3.2.5                        1.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                     1.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                     1.000000
# //:.aspect_rules_js/node_modules/prettier@3.2.5...                     1.000000
# //:create_venv                                                         0.762295
# ...                                                                         ...
# //third_party/bazel/proto:build_event_stream_py...                     1.000000
# //utils:bep_reader.venv                                                0.991803
# //utils:graph_algorithms.py                                            0.942623
# //utils:graph_algorithms_test                                          0.860141
# //utils:graph_algorithms_test.py                                       0.967213
#
# [383 rows x 15 columns]

# %%
df_nodes.nlargest(50, "num_source_descendants")
# Out:
#                                                                       node_class  \
# node_name
# //apps/sbr:rp2040_console                                          native_binary
# //apps/sbr:simulator_console                                       native_binary
# //apps/sbr:simulator_webconsole                                    native_binary
# //examples/pigweed/apps/blinky:simulator_console                   native_binary
# //examples/pigweed/apps/blinky:simulator_webcon...                 native_binary
# //apps/sbr:flash_rp2040                                            native_binary
# //apps/sbr:rp2040_sbr.elf                                          rp2040_binary
# //apps/sbr:flash_rp2350                                            native_binary
# //apps/sbr:rp2350_sbr.elf                                          rp2350_binary
# //apps/sbr:sbr                                                         cc_binary
# //apps/sbr:sbr.stripped                                                  unknown
# //apps/sbr:sbr.dwp                                                       unknown
# //apps/sbr:simulator_sbr                            host_device_simulator_binary
# //examples/pigweed/apps/blinky:blinky                                  cc_binary
# //examples/pigweed/apps/blinky:blinky.stripped                           unknown
# //examples/pigweed/apps/blinky:blinky.dwp                                unknown
# //examples/pigweed/apps/blinky:simulator_blinky     host_device_simulator_binary
# //examples/pigweed/modules/blinky:service                             cc_library
# //examples/pigweed/modules/blinky:blinky_test                            cc_test
# //examples/pigweed/modules/blinky:blinky_test.s...                       unknown
# //examples/pigweed/modules/blinky:blinky_test.dwp                        unknown
# //examples/pigweed/modules/blinky:blinky_test.lib                     cc_library
# //:python_source                                                       filegroup
# //examples/pigweed/modules/blinky:blinky                              cc_library
# //apps/sbr/system:rp2_system                                          cc_library
# //.aspect/bazelrc:update_aspect_bazelrc_presets...                    test_suite
# //hw_services/sbr:service                                             cc_library
# //examples/basic:python_source                                         filegroup
# //apps/bazel_parser:bazel_parser                                       py_binary
# //apps/sbr/system:system                                              label_flag
# //apps/sbr/system:host_system                                         cc_library
# //apps/sbr/system:unspecified_backend                                      alias
# //examples/basic:grpc_test                                               py_test
# //examples/basic/app:hello-world                                       cc_binary
# //examples/basic/app:hello-world.stripped                                unknown
# //examples/basic/app:hello-world.dwp                                     unknown
# //hw_drivers/lis3mdl:lis3mdl_test                                        cc_test
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                               unknown
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                                    unknown
# //tools:check                                                           multirun
# //tools:format                                                          multirun
# //apps/bazel_parser:bazel_parser.venv                               py_venv_rule
# //examples/pigweed/apps/blinky/system:system                          label_flag
# //examples/pigweed/apps/blinky/system:host_system                     cc_library
# //examples/pigweed/apps/blinky/system:unspecifi...                         alias
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                     cc_test
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                            unknown
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                                 unknown
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                              cc_library
# //third_party/delimited_protobuf:delimited_prot...                       py_test
#
#                                                     num_parents  \
# node_name
# //apps/sbr:rp2040_console                                     0
# //apps/sbr:simulator_console                                  0
# //apps/sbr:simulator_webconsole                               0
# //examples/pigweed/apps/blinky:simulator_console              0
# //examples/pigweed/apps/blinky:simulator_webcon...            0
# //apps/sbr:flash_rp2040                                       0
# //apps/sbr:rp2040_sbr.elf                                     2
# //apps/sbr:flash_rp2350                                       0
# //apps/sbr:rp2350_sbr.elf                                     1
# //apps/sbr:sbr                                                5
# //apps/sbr:sbr.stripped                                       0
# //apps/sbr:sbr.dwp                                            0
# //apps/sbr:simulator_sbr                                      2
# //examples/pigweed/apps/blinky:blinky                         3
# //examples/pigweed/apps/blinky:blinky.stripped                0
# //examples/pigweed/apps/blinky:blinky.dwp                     0
# //examples/pigweed/apps/blinky:simulator_blinky               2
# //examples/pigweed/modules/blinky:service                     1
# //examples/pigweed/modules/blinky:blinky_test                 2
# //examples/pigweed/modules/blinky:blinky_test.s...            0
# //examples/pigweed/modules/blinky:blinky_test.dwp             0
# //examples/pigweed/modules/blinky:blinky_test.lib             0
# //:python_source                                              0
# //examples/pigweed/modules/blinky:blinky                      3
# //apps/sbr/system:rp2_system                                  0
# //.aspect/bazelrc:update_aspect_bazelrc_presets...            0
# //hw_services/sbr:service                                     1
# //examples/basic:python_source                                1
# //apps/bazel_parser:bazel_parser                              0
# //apps/sbr/system:system                                      1
# //apps/sbr/system:host_system                                 1
# //apps/sbr/system:unspecified_backend                         1
# //examples/basic:grpc_test                                    0
# //examples/basic/app:hello-world                              2
# //examples/basic/app:hello-world.stripped                     0
# //examples/basic/app:hello-world.dwp                          0
# //hw_drivers/lis3mdl:lis3mdl_test                             2
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                    0
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                         0
# //tools:check                                                 0
# //tools:format                                                0
# //apps/bazel_parser:bazel_parser.venv                         0
# //examples/pigweed/apps/blinky/system:system                  2
# //examples/pigweed/apps/blinky/system:host_system             1
# //examples/pigweed/apps/blinky/system:unspecifi...            1
# //hw_drivers/lis3mdl:lis3mdl_pw_test                          2
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                 0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                      0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                      0
# //third_party/delimited_protobuf:delimited_prot...            0
#
#                                                     num_ancestors  \
# node_name
# //apps/sbr:rp2040_console                                       0
# //apps/sbr:simulator_console                                    0
# //apps/sbr:simulator_webconsole                                 0
# //examples/pigweed/apps/blinky:simulator_console                0
# //examples/pigweed/apps/blinky:simulator_webcon...              0
# //apps/sbr:flash_rp2040                                         0
# //apps/sbr:rp2040_sbr.elf                                       2
# //apps/sbr:flash_rp2350                                         0
# //apps/sbr:rp2350_sbr.elf                                       1
# //apps/sbr:sbr                                                 10
# //apps/sbr:sbr.stripped                                         0
# //apps/sbr:sbr.dwp                                              0
# //apps/sbr:simulator_sbr                                        2
# //examples/pigweed/apps/blinky:blinky                           5
# //examples/pigweed/apps/blinky:blinky.stripped                  0
# //examples/pigweed/apps/blinky:blinky.dwp                       0
# //examples/pigweed/apps/blinky:simulator_blinky                 2
# //examples/pigweed/modules/blinky:service                       6
# //examples/pigweed/modules/blinky:blinky_test                   2
# //examples/pigweed/modules/blinky:blinky_test.s...              0
# //examples/pigweed/modules/blinky:blinky_test.dwp               0
# //examples/pigweed/modules/blinky:blinky_test.lib               0
# //:python_source                                                0
# //examples/pigweed/modules/blinky:blinky                       11
# //apps/sbr/system:rp2_system                                    0
# //.aspect/bazelrc:update_aspect_bazelrc_presets...              0
# //hw_services/sbr:service                                      11
# //examples/basic:python_source                                  1
# //apps/bazel_parser:bazel_parser                                0
# //apps/sbr/system:system                                       11
# //apps/sbr/system:host_system                                  13
# //apps/sbr/system:unspecified_backend                          12
# //examples/basic:grpc_test                                      0
# //examples/basic/app:hello-world                                2
# //examples/basic/app:hello-world.stripped                       0
# //examples/basic/app:hello-world.dwp                            0
# //hw_drivers/lis3mdl:lis3mdl_test                               2
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                      0
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                           0
# //tools:check                                                   0
# //tools:format                                                  0
# //apps/bazel_parser:bazel_parser.venv                           0
# //examples/pigweed/apps/blinky/system:system                   12
# //examples/pigweed/apps/blinky/system:host_system              14
# //examples/pigweed/apps/blinky/system:unspecifi...             13
# //hw_drivers/lis3mdl:lis3mdl_pw_test                            2
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                   0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                        0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                        0
# //third_party/delimited_protobuf:delimited_prot...              0
#
#                                                     num_duration_ancestors  \
# node_name
# //apps/sbr:rp2040_console                                                0
# //apps/sbr:simulator_console                                             0
# //apps/sbr:simulator_webconsole                                          0
# //examples/pigweed/apps/blinky:simulator_console                         0
# //examples/pigweed/apps/blinky:simulator_webcon...                       0
# //apps/sbr:flash_rp2040                                                  0
# //apps/sbr:rp2040_sbr.elf                                                0
# //apps/sbr:flash_rp2350                                                  0
# //apps/sbr:rp2350_sbr.elf                                                0
# //apps/sbr:sbr                                                           0
# //apps/sbr:sbr.stripped                                                  0
# //apps/sbr:sbr.dwp                                                       0
# //apps/sbr:simulator_sbr                                                 0
# //examples/pigweed/apps/blinky:blinky                                    0
# //examples/pigweed/apps/blinky:blinky.stripped                           0
# //examples/pigweed/apps/blinky:blinky.dwp                                0
# //examples/pigweed/apps/blinky:simulator_blinky                          0
# //examples/pigweed/modules/blinky:service                                0
# //examples/pigweed/modules/blinky:blinky_test                            0
# //examples/pigweed/modules/blinky:blinky_test.s...                       0
# //examples/pigweed/modules/blinky:blinky_test.dwp                        0
# //examples/pigweed/modules/blinky:blinky_test.lib                        0
# //:python_source                                                         0
# //examples/pigweed/modules/blinky:blinky                                 1
# //apps/sbr/system:rp2_system                                             0
# //.aspect/bazelrc:update_aspect_bazelrc_presets...                       0
# //hw_services/sbr:service                                                0
# //examples/basic:python_source                                           0
# //apps/bazel_parser:bazel_parser                                         0
# //apps/sbr/system:system                                                 0
# //apps/sbr/system:host_system                                            0
# //apps/sbr/system:unspecified_backend                                    0
# //examples/basic:grpc_test                                               0
# //examples/basic/app:hello-world                                         0
# //examples/basic/app:hello-world.stripped                                0
# //examples/basic/app:hello-world.dwp                                     0
# //hw_drivers/lis3mdl:lis3mdl_test                                        0
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                               0
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                                    0
# //tools:check                                                            0
# //tools:format                                                           0
# //apps/bazel_parser:bazel_parser.venv                                    0
# //examples/pigweed/apps/blinky/system:system                             1
# //examples/pigweed/apps/blinky/system:host_system                        1
# //examples/pigweed/apps/blinky/system:unspecifi...                       1
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                     0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                            0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                                 0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                                 0
# //third_party/delimited_protobuf:delimited_prot...                       0
#
#                                                     num_children  \
# node_name
# //apps/sbr:rp2040_console                                      3
# //apps/sbr:simulator_console                                   3
# //apps/sbr:simulator_webconsole                                3
# //examples/pigweed/apps/blinky:simulator_console               3
# //examples/pigweed/apps/blinky:simulator_webcon...             3
# //apps/sbr:flash_rp2040                                        1
# //apps/sbr:rp2040_sbr.elf                                      1
# //apps/sbr:flash_rp2350                                        1
# //apps/sbr:rp2350_sbr.elf                                      1
# //apps/sbr:sbr                                                 3
# //apps/sbr:sbr.stripped                                        1
# //apps/sbr:sbr.dwp                                             1
# //apps/sbr:simulator_sbr                                       1
# //examples/pigweed/apps/blinky:blinky                          3
# //examples/pigweed/apps/blinky:blinky.stripped                 1
# //examples/pigweed/apps/blinky:blinky.dwp                      1
# //examples/pigweed/apps/blinky:simulator_blinky                1
# //examples/pigweed/modules/blinky:service                      4
# //examples/pigweed/modules/blinky:blinky_test                  2
# //examples/pigweed/modules/blinky:blinky_test.s...             1
# //examples/pigweed/modules/blinky:blinky_test.dwp              1
# //examples/pigweed/modules/blinky:blinky_test.lib              2
# //:python_source                                               6
# //examples/pigweed/modules/blinky:blinky                       4
# //apps/sbr/system:rp2_system                                   4
# //.aspect/bazelrc:update_aspect_bazelrc_presets...             7
# //hw_services/sbr:service                                      5
# //examples/basic:python_source                                 7
# //apps/bazel_parser:bazel_parser                               9
# //apps/sbr/system:system                                       1
# //apps/sbr/system:host_system                                  4
# //apps/sbr/system:unspecified_backend                          1
# //examples/basic:grpc_test                                     6
# //examples/basic/app:hello-world                               4
# //examples/basic/app:hello-world.stripped                      1
# //examples/basic/app:hello-world.dwp                           1
# //hw_drivers/lis3mdl:lis3mdl_test                              5
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                     1
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                          1
# //tools:check                                                  3
# //tools:format                                                 3
# //apps/bazel_parser:bazel_parser.venv                          7
# //examples/pigweed/apps/blinky/system:system                   1
# //examples/pigweed/apps/blinky/system:host_system              4
# //examples/pigweed/apps/blinky/system:unspecifi...             1
# //hw_drivers/lis3mdl:lis3mdl_pw_test                           4
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                  1
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                       1
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                       4
# //third_party/delimited_protobuf:delimited_prot...             5
#
#                                                     num_descendants  \
# node_name
# //apps/sbr:rp2040_console                                        46
# //apps/sbr:simulator_console                                     46
# //apps/sbr:simulator_webconsole                                  46
# //examples/pigweed/apps/blinky:simulator_console                 43
# //examples/pigweed/apps/blinky:simulator_webcon...               43
# //apps/sbr:flash_rp2040                                          31
# //apps/sbr:rp2040_sbr.elf                                        30
# //apps/sbr:flash_rp2350                                          31
# //apps/sbr:rp2350_sbr.elf                                        30
# //apps/sbr:sbr                                                   29
# //apps/sbr:sbr.stripped                                          30
# //apps/sbr:sbr.dwp                                               30
# //apps/sbr:simulator_sbr                                         30
# //examples/pigweed/apps/blinky:blinky                            24
# //examples/pigweed/apps/blinky:blinky.stripped                   25
# //examples/pigweed/apps/blinky:blinky.dwp                        25
# //examples/pigweed/apps/blinky:simulator_blinky                  25
# //examples/pigweed/modules/blinky:service                        22
# //examples/pigweed/modules/blinky:blinky_test                    17
# //examples/pigweed/modules/blinky:blinky_test.s...               18
# //examples/pigweed/modules/blinky:blinky_test.dwp                18
# //examples/pigweed/modules/blinky:blinky_test.lib                17
# //:python_source                                                 20
# //examples/pigweed/modules/blinky:blinky                         15
# //apps/sbr/system:rp2_system                                     15
# //.aspect/bazelrc:update_aspect_bazelrc_presets...               14
# //hw_services/sbr:service                                        15
# //examples/basic:python_source                                   10
# //apps/bazel_parser:bazel_parser                                 23
# //apps/sbr/system:system                                         11
# //apps/sbr/system:host_system                                     9
# //apps/sbr/system:unspecified_backend                            10
# //examples/basic:grpc_test                                       17
# //examples/basic/app:hello-world                                 13
# //examples/basic/app:hello-world.stripped                        14
# //examples/basic/app:hello-world.dwp                             14
# //hw_drivers/lis3mdl:lis3mdl_test                                12
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                       13
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                            13
# //tools:check                                                    16
# //tools:format                                                   16
# //apps/bazel_parser:bazel_parser.venv                            21
# //examples/pigweed/apps/blinky/system:system                      9
# //examples/pigweed/apps/blinky/system:host_system                 7
# //examples/pigweed/apps/blinky/system:unspecifi...                8
# //hw_drivers/lis3mdl:lis3mdl_pw_test                             10
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                    11
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                         11
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                         10
# //third_party/delimited_protobuf:delimited_prot...               11
#
#                                                     num_source_descendants  \
# node_name
# //apps/sbr:rp2040_console                                               17
# //apps/sbr:simulator_console                                            17
# //apps/sbr:simulator_webconsole                                         17
# //examples/pigweed/apps/blinky:simulator_console                        17
# //examples/pigweed/apps/blinky:simulator_webcon...                      17
# //apps/sbr:flash_rp2040                                                 14
# //apps/sbr:rp2040_sbr.elf                                               14
# //apps/sbr:flash_rp2350                                                 14
# //apps/sbr:rp2350_sbr.elf                                               14
# //apps/sbr:sbr                                                          14
# //apps/sbr:sbr.stripped                                                 14
# //apps/sbr:sbr.dwp                                                      14
# //apps/sbr:simulator_sbr                                                14
# //examples/pigweed/apps/blinky:blinky                                   13
# //examples/pigweed/apps/blinky:blinky.stripped                          13
# //examples/pigweed/apps/blinky:blinky.dwp                               13
# //examples/pigweed/apps/blinky:simulator_blinky                         13
# //examples/pigweed/modules/blinky:service                               12
# //examples/pigweed/modules/blinky:blinky_test                           10
# //examples/pigweed/modules/blinky:blinky_test.s...                      10
# //examples/pigweed/modules/blinky:blinky_test.dwp                       10
# //examples/pigweed/modules/blinky:blinky_test.lib                       10
# //:python_source                                                         9
# //examples/pigweed/modules/blinky:blinky                                 9
# //apps/sbr/system:rp2_system                                             8
# //.aspect/bazelrc:update_aspect_bazelrc_presets...                       7
# //hw_services/sbr:service                                                7
# //examples/basic:python_source                                           6
# //apps/bazel_parser:bazel_parser                                         6
# //apps/sbr/system:system                                                 6
# //apps/sbr/system:host_system                                            6
# //apps/sbr/system:unspecified_backend                                    6
# //examples/basic:grpc_test                                               6
# //examples/basic/app:hello-world                                         6
# //examples/basic/app:hello-world.stripped                                6
# //examples/basic/app:hello-world.dwp                                     6
# //hw_drivers/lis3mdl:lis3mdl_test                                        6
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                               6
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                                    6
# //tools:check                                                            6
# //tools:format                                                           6
# //apps/bazel_parser:bazel_parser.venv                                    5
# //examples/pigweed/apps/blinky/system:system                             5
# //examples/pigweed/apps/blinky/system:host_system                        5
# //examples/pigweed/apps/blinky/system:unspecifi...                       5
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                     5
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                            5
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                                 5
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                                 5
# //third_party/delimited_protobuf:delimited_prot...                       5
#
#                                                     pagerank   hubs_metric  \
# node_name
# //apps/sbr:rp2040_console                           0.001179 -4.738377e-17
# //apps/sbr:simulator_console                        0.001179 -5.215664e-17
# //apps/sbr:simulator_webconsole                     0.001179 -5.215664e-17
# //examples/pigweed/apps/blinky:simulator_console    0.001179 -5.203036e-17
# //examples/pigweed/apps/blinky:simulator_webcon...  0.001179 -5.203036e-17
# //apps/sbr:flash_rp2040                             0.001179 -4.234277e-18
# //apps/sbr:rp2040_sbr.elf                           0.002516 -6.260822e-18
# //apps/sbr:flash_rp2350                             0.001179  3.896451e-19
# //apps/sbr:rp2350_sbr.elf                           0.002182 -6.260822e-18
# //apps/sbr:sbr                                      0.008747 -7.355863e-19
# //apps/sbr:sbr.stripped                             0.001179 -6.260822e-18
# //apps/sbr:sbr.dwp                                  0.001179 -6.260822e-18
# //apps/sbr:simulator_sbr                            0.001848 -6.260822e-18
# //examples/pigweed/apps/blinky:blinky               0.004754  2.642117e-18
# //examples/pigweed/apps/blinky:blinky.stripped      0.001179 -5.867187e-20
# //examples/pigweed/apps/blinky:blinky.dwp           0.001179 -5.867187e-20
# //examples/pigweed/apps/blinky:simulator_blinky     0.001848 -5.867187e-20
# //examples/pigweed/modules/blinky:service           0.002526 -2.070899e-18
# //examples/pigweed/modules/blinky:blinky_test       0.003184 -1.128925e-18
# //examples/pigweed/modules/blinky:blinky_test.s...  0.001179 -1.843101e-19
# //examples/pigweed/modules/blinky:blinky_test.dwp   0.001179 -1.843101e-19
# //examples/pigweed/modules/blinky:blinky_test.lib   0.001179 -1.128925e-18
# //:python_source                                    0.001179  8.046122e-18
# //examples/pigweed/modules/blinky:blinky            0.003570  4.297644e-18
# //apps/sbr/system:rp2_system                        0.001179  1.054447e-16
# //.aspect/bazelrc:update_aspect_bazelrc_presets...  0.001179  4.721142e-18
# //hw_services/sbr:service                           0.003658  2.159337e-16
# //examples/basic:python_source                      0.001346  3.144422e-02
# //apps/bazel_parser:bazel_parser                    0.001179  1.356512e-01
# //apps/sbr/system:system                            0.003658  5.549954e-20
# //apps/sbr/system:host_system                       0.004825  1.650401e-17
# //apps/sbr/system:unspecified_backend               0.004289  3.280873e-20
# //examples/basic:grpc_test                          0.001179  8.653275e-02
# //examples/basic/app:hello-world                    0.003184  1.668513e-18
# //examples/basic/app:hello-world.stripped           0.001179 -2.340566e-19
# //examples/basic/app:hello-world.dwp                0.001179 -2.340566e-19
# //hw_drivers/lis3mdl:lis3mdl_test                   0.003184  2.791170e-16
# //hw_drivers/lis3mdl:lis3mdl_test.stripped          0.001179  6.630310e-19
# //hw_drivers/lis3mdl:lis3mdl_test.dwp               0.001179  6.630310e-19
# //tools:check                                       0.001179 -2.688414e-18
# //tools:format                                      0.001179 -3.463149e-18
# //apps/bazel_parser:bazel_parser.venv               0.001179  1.177093e-01
# //examples/pigweed/apps/blinky/system:system        0.003285 -1.283977e-20
# //examples/pigweed/apps/blinky/system:host_system   0.004555  8.019312e-18
# //examples/pigweed/apps/blinky/system:unspecifi...  0.003972  9.434529e-21
# //hw_drivers/lis3mdl:lis3mdl_pw_test                0.003184  2.808773e-16
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped       0.001179  9.417787e-20
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp            0.001179  9.417787e-20
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib            0.001179  2.808773e-16
# //third_party/delimited_protobuf:delimited_prot...  0.001179  7.492403e-02
#
#                                                     authorities_metric  \
# node_name
# //apps/sbr:rp2040_console                                -1.428597e-18
# //apps/sbr:simulator_console                              4.074089e-18
# //apps/sbr:simulator_webconsole                           6.908672e-18
# //examples/pigweed/apps/blinky:simulator_console         -1.112763e-18
# //examples/pigweed/apps/blinky:simulator_webcon...        2.328585e-18
# //apps/sbr:flash_rp2040                                   6.995155e-19
# //apps/sbr:rp2040_sbr.elf                                -1.474360e-17
# //apps/sbr:flash_rp2350                                  -1.094188e-20
# //apps/sbr:rp2350_sbr.elf                                 1.356730e-18
# //apps/sbr:sbr                                           -2.179996e-17
# //apps/sbr:sbr.stripped                                   7.775986e-19
# //apps/sbr:sbr.dwp                                        7.650061e-20
# //apps/sbr:simulator_sbr                                 -3.136254e-17
# //examples/pigweed/apps/blinky:blinky                    -2.042933e-19
# //examples/pigweed/apps/blinky:blinky.stripped            5.903173e-18
# //examples/pigweed/apps/blinky:blinky.dwp                -2.183133e-18
# //examples/pigweed/apps/blinky:simulator_blinky          -3.092286e-17
# //examples/pigweed/modules/blinky:service                 1.242992e-19
# //examples/pigweed/modules/blinky:blinky_test            -6.417612e-19
# //examples/pigweed/modules/blinky:blinky_test.s...       -8.083089e-19
# //examples/pigweed/modules/blinky:blinky_test.dwp        -5.624033e-19
# //examples/pigweed/modules/blinky:blinky_test.lib         2.853630e-18
# //:python_source                                         -8.379072e-19
# //examples/pigweed/modules/blinky:blinky                 -3.265262e-18
# //apps/sbr/system:rp2_system                             -3.627329e-18
# //.aspect/bazelrc:update_aspect_bazelrc_presets...       -4.793893e-19
# //hw_services/sbr:service                                 9.290826e-19
# //examples/basic:python_source                            5.150645e-19
# //apps/bazel_parser:bazel_parser                         -2.888537e-18
# //apps/sbr/system:system                                 -7.304664e-19
# //apps/sbr/system:host_system                             1.142388e-19
# //apps/sbr/system:unspecified_backend                     1.932474e-19
# //examples/basic:grpc_test                               -3.529188e-19
# //examples/basic/app:hello-world                         -8.149766e-19
# //examples/basic/app:hello-world.stripped                -9.217411e-19
# //examples/basic/app:hello-world.dwp                      7.641867e-18
# //hw_drivers/lis3mdl:lis3mdl_test                         2.308650e-18
# //hw_drivers/lis3mdl:lis3mdl_test.stripped               -5.470621e-19
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                    -1.508533e-18
# //tools:check                                             1.410747e-18
# //tools:format                                           -9.166112e-19
# //apps/bazel_parser:bazel_parser.venv                    -2.394931e-18
# //examples/pigweed/apps/blinky/system:system              6.713252e-18
# //examples/pigweed/apps/blinky/system:host_system         3.285069e-20
# //examples/pigweed/apps/blinky/system:unspecifi...       -4.470762e-20
# //hw_drivers/lis3mdl:lis3mdl_pw_test                      3.279240e-19
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped            -3.688719e-18
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                  3.184802e-18
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                 -3.521666e-18
# //third_party/delimited_protobuf:delimited_prot...        4.923805e-18
#
#                                                     node_duration_s  \
# node_name
# //apps/sbr:rp2040_console                                     0.000
# //apps/sbr:simulator_console                                  0.000
# //apps/sbr:simulator_webconsole                               0.000
# //examples/pigweed/apps/blinky:simulator_console              0.000
# //examples/pigweed/apps/blinky:simulator_webcon...            0.000
# //apps/sbr:flash_rp2040                                       0.000
# //apps/sbr:rp2040_sbr.elf                                     0.000
# //apps/sbr:flash_rp2350                                       0.000
# //apps/sbr:rp2350_sbr.elf                                     0.000
# //apps/sbr:sbr                                                0.000
# //apps/sbr:sbr.stripped                                       0.000
# //apps/sbr:sbr.dwp                                            0.000
# //apps/sbr:simulator_sbr                                      0.000
# //examples/pigweed/apps/blinky:blinky                         0.000
# //examples/pigweed/apps/blinky:blinky.stripped                0.000
# //examples/pigweed/apps/blinky:blinky.dwp                     0.000
# //examples/pigweed/apps/blinky:simulator_blinky               0.000
# //examples/pigweed/modules/blinky:service                     0.000
# //examples/pigweed/modules/blinky:blinky_test                 3.246
# //examples/pigweed/modules/blinky:blinky_test.s...            0.000
# //examples/pigweed/modules/blinky:blinky_test.dwp             0.000
# //examples/pigweed/modules/blinky:blinky_test.lib             0.000
# //:python_source                                              0.000
# //examples/pigweed/modules/blinky:blinky                      0.000
# //apps/sbr/system:rp2_system                                  0.000
# //.aspect/bazelrc:update_aspect_bazelrc_presets...            0.000
# //hw_services/sbr:service                                     0.000
# //examples/basic:python_source                                0.000
# //apps/bazel_parser:bazel_parser                              0.000
# //apps/sbr/system:system                                      0.000
# //apps/sbr/system:host_system                                 0.000
# //apps/sbr/system:unspecified_backend                         0.000
# //examples/basic:grpc_test                                    0.638
# //examples/basic/app:hello-world                              0.000
# //examples/basic/app:hello-world.stripped                     0.000
# //examples/basic/app:hello-world.dwp                          0.000
# //hw_drivers/lis3mdl:lis3mdl_test                             0.024
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                    0.000
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                         0.000
# //tools:check                                                 0.000
# //tools:format                                                0.000
# //apps/bazel_parser:bazel_parser.venv                         0.000
# //examples/pigweed/apps/blinky/system:system                  0.000
# //examples/pigweed/apps/blinky/system:host_system             0.000
# //examples/pigweed/apps/blinky/system:unspecifi...            0.000
# //hw_drivers/lis3mdl:lis3mdl_pw_test                          0.026
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                 0.000
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                      0.000
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                      0.000
# //third_party/delimited_protobuf:delimited_prot...            0.480
#
#                                                     group_duration_s  \
# node_name
# //apps/sbr:rp2040_console                                      0.000
# //apps/sbr:simulator_console                                   0.000
# //apps/sbr:simulator_webconsole                                0.000
# //examples/pigweed/apps/blinky:simulator_console               0.000
# //examples/pigweed/apps/blinky:simulator_webcon...             0.000
# //apps/sbr:flash_rp2040                                        0.000
# //apps/sbr:rp2040_sbr.elf                                      0.000
# //apps/sbr:flash_rp2350                                        0.000
# //apps/sbr:rp2350_sbr.elf                                      0.000
# //apps/sbr:sbr                                                 0.000
# //apps/sbr:sbr.stripped                                        0.000
# //apps/sbr:sbr.dwp                                             0.000
# //apps/sbr:simulator_sbr                                       0.000
# //examples/pigweed/apps/blinky:blinky                          0.000
# //examples/pigweed/apps/blinky:blinky.stripped                 0.000
# //examples/pigweed/apps/blinky:blinky.dwp                      0.000
# //examples/pigweed/apps/blinky:simulator_blinky                0.000
# //examples/pigweed/modules/blinky:service                      0.000
# //examples/pigweed/modules/blinky:blinky_test                  3.246
# //examples/pigweed/modules/blinky:blinky_test.s...             0.000
# //examples/pigweed/modules/blinky:blinky_test.dwp              0.000
# //examples/pigweed/modules/blinky:blinky_test.lib              0.000
# //:python_source                                               0.000
# //examples/pigweed/modules/blinky:blinky                       3.246
# //apps/sbr/system:rp2_system                                   0.000
# //.aspect/bazelrc:update_aspect_bazelrc_presets...             0.000
# //hw_services/sbr:service                                      0.000
# //examples/basic:python_source                                 0.000
# //apps/bazel_parser:bazel_parser                               0.000
# //apps/sbr/system:system                                       0.000
# //apps/sbr/system:host_system                                  0.000
# //apps/sbr/system:unspecified_backend                          0.000
# //examples/basic:grpc_test                                     0.638
# //examples/basic/app:hello-world                               0.000
# //examples/basic/app:hello-world.stripped                      0.000
# //examples/basic/app:hello-world.dwp                           0.000
# //hw_drivers/lis3mdl:lis3mdl_test                              0.024
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                     0.000
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                          0.000
# //tools:check                                                  0.000
# //tools:format                                                 0.000
# //apps/bazel_parser:bazel_parser.venv                          0.000
# //examples/pigweed/apps/blinky/system:system                   3.246
# //examples/pigweed/apps/blinky/system:host_system              3.246
# //examples/pigweed/apps/blinky/system:unspecifi...             3.246
# //hw_drivers/lis3mdl:lis3mdl_pw_test                           0.026
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                  0.000
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                       0.000
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                       0.000
# //third_party/delimited_protobuf:delimited_prot...             0.480
#
#                                                     expected_duration_s  \
# node_name
# //apps/sbr:rp2040_console                                      0.000000
# //apps/sbr:simulator_console                                   0.000000
# //apps/sbr:simulator_webconsole                                0.000000
# //examples/pigweed/apps/blinky:simulator_console               0.000000
# //examples/pigweed/apps/blinky:simulator_webcon...             0.000000
# //apps/sbr:flash_rp2040                                        0.000000
# //apps/sbr:rp2040_sbr.elf                                      0.000000
# //apps/sbr:flash_rp2350                                        0.000000
# //apps/sbr:rp2350_sbr.elf                                      0.000000
# //apps/sbr:sbr                                                 0.000000
# //apps/sbr:sbr.stripped                                        0.000000
# //apps/sbr:sbr.dwp                                             0.000000
# //apps/sbr:simulator_sbr                                       0.000000
# //examples/pigweed/apps/blinky:blinky                          0.000000
# //examples/pigweed/apps/blinky:blinky.stripped                 0.000000
# //examples/pigweed/apps/blinky:blinky.dwp                      0.000000
# //examples/pigweed/apps/blinky:simulator_blinky                0.000000
# //examples/pigweed/modules/blinky:service                      0.000000
# //examples/pigweed/modules/blinky:blinky_test                  0.472581
# //examples/pigweed/modules/blinky:blinky_test.s...             0.000000
# //examples/pigweed/modules/blinky:blinky_test.dwp              0.000000
# //examples/pigweed/modules/blinky:blinky_test.lib              0.000000
# //:python_source                                               0.000000
# //examples/pigweed/modules/blinky:blinky                       0.449660
# //apps/sbr/system:rp2_system                                   0.000000
# //.aspect/bazelrc:update_aspect_bazelrc_presets...             0.000000
# //hw_services/sbr:service                                      0.000000
# //examples/basic:python_source                                 0.000000
# //apps/bazel_parser:bazel_parser                               0.000000
# //apps/sbr/system:system                                       0.000000
# //apps/sbr/system:host_system                                  0.000000
# //apps/sbr/system:unspecified_backend                          0.000000
# //examples/basic:grpc_test                                     0.124625
# //examples/basic/app:hello-world                               0.000000
# //examples/basic/app:hello-world.stripped                      0.000000
# //examples/basic/app:hello-world.dwp                           0.000000
# //hw_drivers/lis3mdl:lis3mdl_test                              0.001718
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                     0.000000
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                          0.000000
# //tools:check                                                  0.000000
# //tools:format                                                 0.000000
# //apps/bazel_parser:bazel_parser.venv                          0.000000
# //examples/pigweed/apps/blinky/system:system                   0.307701
# //examples/pigweed/apps/blinky/system:host_system              0.307701
# //examples/pigweed/apps/blinky/system:unspecifi...             0.307701
# //hw_drivers/lis3mdl:lis3mdl_pw_test                           0.001459
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                  0.000000
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                       0.000000
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                       0.000000
# //third_party/delimited_protobuf:delimited_prot...             0.049152
#
#                                                     node_probability_cache_hit  \
# node_name
# //apps/sbr:rp2040_console                                                  1.0
# //apps/sbr:simulator_console                                               1.0
# //apps/sbr:simulator_webconsole                                            1.0
# //examples/pigweed/apps/blinky:simulator_console                           1.0
# //examples/pigweed/apps/blinky:simulator_webcon...                         1.0
# //apps/sbr:flash_rp2040                                                    1.0
# //apps/sbr:rp2040_sbr.elf                                                  1.0
# //apps/sbr:flash_rp2350                                                    1.0
# //apps/sbr:rp2350_sbr.elf                                                  1.0
# //apps/sbr:sbr                                                             1.0
# //apps/sbr:sbr.stripped                                                    1.0
# //apps/sbr:sbr.dwp                                                         1.0
# //apps/sbr:simulator_sbr                                                   1.0
# //examples/pigweed/apps/blinky:blinky                                      1.0
# //examples/pigweed/apps/blinky:blinky.stripped                             1.0
# //examples/pigweed/apps/blinky:blinky.dwp                                  1.0
# //examples/pigweed/apps/blinky:simulator_blinky                            1.0
# //examples/pigweed/modules/blinky:service                                  1.0
# //examples/pigweed/modules/blinky:blinky_test                              1.0
# //examples/pigweed/modules/blinky:blinky_test.s...                         1.0
# //examples/pigweed/modules/blinky:blinky_test.dwp                          1.0
# //examples/pigweed/modules/blinky:blinky_test.lib                          1.0
# //:python_source                                                           1.0
# //examples/pigweed/modules/blinky:blinky                                   1.0
# //apps/sbr/system:rp2_system                                               1.0
# //.aspect/bazelrc:update_aspect_bazelrc_presets...                         1.0
# //hw_services/sbr:service                                                  1.0
# //examples/basic:python_source                                             1.0
# //apps/bazel_parser:bazel_parser                                           1.0
# //apps/sbr/system:system                                                   1.0
# //apps/sbr/system:host_system                                              1.0
# //apps/sbr/system:unspecified_backend                                      1.0
# //examples/basic:grpc_test                                                 1.0
# //examples/basic/app:hello-world                                           1.0
# //examples/basic/app:hello-world.stripped                                  1.0
# //examples/basic/app:hello-world.dwp                                       1.0
# //hw_drivers/lis3mdl:lis3mdl_test                                          1.0
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                                 1.0
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                                      1.0
# //tools:check                                                              1.0
# //tools:format                                                             1.0
# //apps/bazel_parser:bazel_parser.venv                                      1.0
# //examples/pigweed/apps/blinky/system:system                               1.0
# //examples/pigweed/apps/blinky/system:host_system                          1.0
# //examples/pigweed/apps/blinky/system:unspecifi...                         1.0
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                       1.0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                              1.0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                                   1.0
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                                   1.0
# //third_party/delimited_protobuf:delimited_prot...                         1.0
#
#                                                     group_probability_cache_hit
# node_name
# //apps/sbr:rp2040_console                                              0.813525
# //apps/sbr:simulator_console                                           0.813525
# //apps/sbr:simulator_webconsole                                        0.813525
# //examples/pigweed/apps/blinky:simulator_console                       0.767292
# //examples/pigweed/apps/blinky:simulator_webcon...                     0.767292
# //apps/sbr:flash_rp2040                                                0.854943
# //apps/sbr:rp2040_sbr.elf                                              0.854943
# //apps/sbr:flash_rp2350                                                0.854943
# //apps/sbr:rp2350_sbr.elf                                              0.854943
# //apps/sbr:sbr                                                         0.854943
# //apps/sbr:sbr.stripped                                                0.854943
# //apps/sbr:sbr.dwp                                                     0.854943
# //apps/sbr:simulator_sbr                                               0.854943
# //examples/pigweed/apps/blinky:blinky                                  0.813020
# //examples/pigweed/apps/blinky:blinky.stripped                         0.813020
# //examples/pigweed/apps/blinky:blinky.dwp                              0.813020
# //examples/pigweed/apps/blinky:simulator_blinky                        0.813020
# //examples/pigweed/modules/blinky:service                              0.833516
# //examples/pigweed/modules/blinky:blinky_test                          0.854411
# //examples/pigweed/modules/blinky:blinky_test.s...                     0.854411
# //examples/pigweed/modules/blinky:blinky_test.dwp                      0.854411
# //examples/pigweed/modules/blinky:blinky_test.lib                      0.854411
# //:python_source                                                       0.671789
# //examples/pigweed/modules/blinky:blinky                               0.861473
# //apps/sbr/system:rp2_system                                           0.905707
# //.aspect/bazelrc:update_aspect_bazelrc_presets...                     0.944015
# //hw_services/sbr:service                                              0.928476
# //examples/basic:python_source                                         0.784434
# //apps/bazel_parser:bazel_parser                                       0.761486
# //apps/sbr/system:system                                               0.936149
# //apps/sbr/system:host_system                                          0.936149
# //apps/sbr/system:unspecified_backend                                  0.936149
# //examples/basic:grpc_test                                             0.804663
# //examples/basic/app:hello-world                                       0.883008
# //examples/basic/app:hello-world.stripped                              0.883008
# //examples/basic/app:hello-world.dwp                                   0.883008
# //hw_drivers/lis3mdl:lis3mdl_test                                      0.928412
# //hw_drivers/lis3mdl:lis3mdl_test.stripped                             0.928412
# //hw_drivers/lis3mdl:lis3mdl_test.dwp                                  0.928412
# //tools:check                                                          0.890302
# //tools:format                                                         0.890302
# //apps/bazel_parser:bazel_parser.venv                                  0.860197
# //examples/pigweed/apps/blinky/system:system                           0.905206
# //examples/pigweed/apps/blinky/system:host_system                      0.905206
# //examples/pigweed/apps/blinky/system:unspecifi...                     0.905206
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                   0.943886
# //hw_drivers/lis3mdl:lis3mdl_pw_test.stripped                          0.943886
# //hw_drivers/lis3mdl:lis3mdl_pw_test.dwp                               0.943886
# //hw_drivers/lis3mdl:lis3mdl_pw_test.lib                               0.943886
# //third_party/delimited_protobuf:delimited_prot...                     0.897599

# %%
# 5 nodes that take time, sorted by largest number of source_descendants
# XXX: How to select based on this weighted by node_duration_s
df_nodes.loc[df_nodes["node_duration_s"] > 0].sort_values(
    ["num_source_descendants", "node_duration_s"], ascending=False
)[:5]
# Out:
#                                                    node_class  num_parents  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test         cc_test            2
# //examples/basic:grpc_test                            py_test            0
# //hw_drivers/lis3mdl:lis3mdl_test                     cc_test            2
# //third_party/delimited_protobuf:delimited_prot...    py_test            0
# //hw_drivers/lis3mdl:lis3mdl_pw_test                  cc_test            2
#
#                                                     num_ancestors  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                   2
# //examples/basic:grpc_test                                      0
# //hw_drivers/lis3mdl:lis3mdl_test                               2
# //third_party/delimited_protobuf:delimited_prot...              0
# //hw_drivers/lis3mdl:lis3mdl_pw_test                            2
#
#                                                     num_duration_ancestors  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                            0
# //examples/basic:grpc_test                                               0
# //hw_drivers/lis3mdl:lis3mdl_test                                        0
# //third_party/delimited_protobuf:delimited_prot...                       0
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                     0
#
#                                                     num_children  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                  2
# //examples/basic:grpc_test                                     6
# //hw_drivers/lis3mdl:lis3mdl_test                              5
# //third_party/delimited_protobuf:delimited_prot...             5
# //hw_drivers/lis3mdl:lis3mdl_pw_test                           4
#
#                                                     num_descendants  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                    17
# //examples/basic:grpc_test                                       17
# //hw_drivers/lis3mdl:lis3mdl_test                                12
# //third_party/delimited_protobuf:delimited_prot...               11
# //hw_drivers/lis3mdl:lis3mdl_pw_test                             10
#
#                                                     num_source_descendants  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                           10
# //examples/basic:grpc_test                                               6
# //hw_drivers/lis3mdl:lis3mdl_test                                        6
# //third_party/delimited_protobuf:delimited_prot...                       5
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                     5
#
#                                                     pagerank   hubs_metric  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test       0.003184 -1.128925e-18
# //examples/basic:grpc_test                          0.001179  8.653275e-02
# //hw_drivers/lis3mdl:lis3mdl_test                   0.003184  2.791170e-16
# //third_party/delimited_protobuf:delimited_prot...  0.001179  7.492403e-02
# //hw_drivers/lis3mdl:lis3mdl_pw_test                0.003184  2.808773e-16
#
#                                                     authorities_metric  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test            -6.417612e-19
# //examples/basic:grpc_test                               -3.529188e-19
# //hw_drivers/lis3mdl:lis3mdl_test                         2.308650e-18
# //third_party/delimited_protobuf:delimited_prot...        4.923805e-18
# //hw_drivers/lis3mdl:lis3mdl_pw_test                      3.279240e-19
#
#                                                     node_duration_s  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                 3.246
# //examples/basic:grpc_test                                    0.638
# //hw_drivers/lis3mdl:lis3mdl_test                             0.024
# //third_party/delimited_protobuf:delimited_prot...            0.480
# //hw_drivers/lis3mdl:lis3mdl_pw_test                          0.026
#
#                                                     group_duration_s  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                  3.246
# //examples/basic:grpc_test                                     0.638
# //hw_drivers/lis3mdl:lis3mdl_test                              0.024
# //third_party/delimited_protobuf:delimited_prot...             0.480
# //hw_drivers/lis3mdl:lis3mdl_pw_test                           0.026
#
#                                                     expected_duration_s  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                  0.472581
# //examples/basic:grpc_test                                     0.124625
# //hw_drivers/lis3mdl:lis3mdl_test                              0.001718
# //third_party/delimited_protobuf:delimited_prot...             0.049152
# //hw_drivers/lis3mdl:lis3mdl_pw_test                           0.001459
#
#                                                     node_probability_cache_hit  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                              1.0
# //examples/basic:grpc_test                                                 1.0
# //hw_drivers/lis3mdl:lis3mdl_test                                          1.0
# //third_party/delimited_protobuf:delimited_prot...                         1.0
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                       1.0
#
#                                                     group_probability_cache_hit
# node_name
# //examples/pigweed/modules/blinky:blinky_test                          0.854411
# //examples/basic:grpc_test                                             0.804663
# //hw_drivers/lis3mdl:lis3mdl_test                                      0.928412
# //third_party/delimited_protobuf:delimited_prot...                     0.897599
# //hw_drivers/lis3mdl:lis3mdl_pw_test                                   0.943886

# %%
df_nodes["weighted_source"] = (
    df_nodes["node_duration_s"] * df_nodes["num_source_descendants"]
)

# %%
# Find the most impacted tests
df_nodes.nlargest(10, "weighted_source")
# Out:
#                                                           node_class  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                cc_test
# //:requirements_test                                pip_compile_test
# //examples/basic:grpc_test                                   py_test
# //examples/basic:hello_test                                  py_test
# //utils:graph_algorithms_test                                py_test
# //third_party/delimited_protobuf:delimited_prot...           py_test
# //examples/basic/lib:hello_test                              cc_test
# //examples/bazel:cat_bin1_pure_test                          sh_test
# //hw_drivers/lis3mdl:lis3mdl_test                            cc_test
# //:gazelle_python_manifest.test                              go_test
#
#                                                     num_parents  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                 2
# //:requirements_test                                          0
# //examples/basic:grpc_test                                    0
# //examples/basic:hello_test                                   0
# //utils:graph_algorithms_test                                 0
# //third_party/delimited_protobuf:delimited_prot...            0
# //examples/basic/lib:hello_test                               2
# //examples/bazel:cat_bin1_pure_test                           0
# //hw_drivers/lis3mdl:lis3mdl_test                             2
# //:gazelle_python_manifest.test                               0
#
#                                                     num_ancestors  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                   2
# //:requirements_test                                            0
# //examples/basic:grpc_test                                      0
# //examples/basic:hello_test                                     0
# //utils:graph_algorithms_test                                   0
# //third_party/delimited_protobuf:delimited_prot...              0
# //examples/basic/lib:hello_test                                 2
# //examples/bazel:cat_bin1_pure_test                             0
# //hw_drivers/lis3mdl:lis3mdl_test                               2
# //:gazelle_python_manifest.test                                 0
#
#                                                     num_duration_ancestors  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                            0
# //:requirements_test                                                     0
# //examples/basic:grpc_test                                               0
# //examples/basic:hello_test                                              0
# //utils:graph_algorithms_test                                            0
# //third_party/delimited_protobuf:delimited_prot...                       0
# //examples/basic/lib:hello_test                                          0
# //examples/bazel:cat_bin1_pure_test                                      0
# //hw_drivers/lis3mdl:lis3mdl_test                                        0
# //:gazelle_python_manifest.test                                          0
#
#                                                     num_children  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                  2
# //:requirements_test                                           3
# //examples/basic:grpc_test                                     6
# //examples/basic:hello_test                                    4
# //utils:graph_algorithms_test                                  4
# //third_party/delimited_protobuf:delimited_prot...             5
# //examples/basic/lib:hello_test                                2
# //examples/bazel:cat_bin1_pure_test                            2
# //hw_drivers/lis3mdl:lis3mdl_test                              5
# //:gazelle_python_manifest.test                                2
#
#                                                     num_descendants  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                    17
# //:requirements_test                                              3
# //examples/basic:grpc_test                                       17
# //examples/basic:hello_test                                       9
# //utils:graph_algorithms_test                                     5
# //third_party/delimited_protobuf:delimited_prot...               11
# //examples/basic/lib:hello_test                                   3
# //examples/bazel:cat_bin1_pure_test                               9
# //hw_drivers/lis3mdl:lis3mdl_test                                12
# //:gazelle_python_manifest.test                                   2
#
#                                                     num_source_descendants  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                           10
# //:requirements_test                                                     2
# //examples/basic:grpc_test                                               6
# //examples/basic:hello_test                                              4
# //utils:graph_algorithms_test                                            4
# //third_party/delimited_protobuf:delimited_prot...                       5
# //examples/basic/lib:hello_test                                          2
# //examples/bazel:cat_bin1_pure_test                                      2
# //hw_drivers/lis3mdl:lis3mdl_test                                        6
# //:gazelle_python_manifest.test                                          2
#
#                                                     pagerank   hubs_metric  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test       0.003184 -1.128925e-18
# //:requirements_test                                0.001179  1.355134e-17
# //examples/basic:grpc_test                          0.001179  8.653275e-02
# //examples/basic:hello_test                         0.001179  7.118386e-02
# //utils:graph_algorithms_test                       0.001179  6.229455e-02
# //third_party/delimited_protobuf:delimited_prot...  0.001179  7.492403e-02
# //examples/basic/lib:hello_test                     0.003184  2.253093e-17
# //examples/bazel:cat_bin1_pure_test                 0.001179 -7.728416e-19
# //hw_drivers/lis3mdl:lis3mdl_test                   0.003184  2.791170e-16
# //:gazelle_python_manifest.test                     0.001179  1.053722e-17
#
#                                                     authorities_metric  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test            -6.417612e-19
# //:requirements_test                                      1.094308e-18
# //examples/basic:grpc_test                               -3.529188e-19
# //examples/basic:hello_test                              -5.868066e-18
# //utils:graph_algorithms_test                            -7.205433e-19
# //third_party/delimited_protobuf:delimited_prot...        4.923805e-18
# //examples/basic/lib:hello_test                          -5.027423e-20
# //examples/bazel:cat_bin1_pure_test                       8.258002e-18
# //hw_drivers/lis3mdl:lis3mdl_test                         2.308650e-18
# //:gazelle_python_manifest.test                          -2.055098e-18
#
#                                                     node_duration_s  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                 3.246
# //:requirements_test                                          2.809
# //examples/basic:grpc_test                                    0.638
# //examples/basic:hello_test                                   0.721
# //utils:graph_algorithms_test                                 0.691
# //third_party/delimited_protobuf:delimited_prot...            0.480
# //examples/basic/lib:hello_test                               0.130
# //examples/bazel:cat_bin1_pure_test                           0.104
# //hw_drivers/lis3mdl:lis3mdl_test                             0.024
# //:gazelle_python_manifest.test                               0.067
#
#                                                     group_duration_s  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                  3.246
# //:requirements_test                                           2.809
# //examples/basic:grpc_test                                     0.638
# //examples/basic:hello_test                                    0.721
# //utils:graph_algorithms_test                                  0.691
# //third_party/delimited_protobuf:delimited_prot...             0.480
# //examples/basic/lib:hello_test                                0.130
# //examples/bazel:cat_bin1_pure_test                            0.104
# //hw_drivers/lis3mdl:lis3mdl_test                              0.024
# //:gazelle_python_manifest.test                                0.067
#
#                                                     expected_duration_s  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                  0.472581
# //:requirements_test                                           0.930986
# //examples/basic:grpc_test                                     0.124625
# //examples/basic:hello_test                                    0.090053
# //utils:graph_algorithms_test                                  0.096643
# //third_party/delimited_protobuf:delimited_prot...             0.049152
# //examples/basic/lib:hello_test                                0.004227
# //examples/bazel:cat_bin1_pure_test                            0.001698
# //hw_drivers/lis3mdl:lis3mdl_test                              0.001718
# //:gazelle_python_manifest.test                                0.028485
#
#                                                     node_probability_cache_hit  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                              1.0
# //:requirements_test                                                       1.0
# //examples/basic:grpc_test                                                 1.0
# //examples/basic:hello_test                                                1.0
# //utils:graph_algorithms_test                                              1.0
# //third_party/delimited_protobuf:delimited_prot...                         1.0
# //examples/basic/lib:hello_test                                            1.0
# //examples/bazel:cat_bin1_pure_test                                        1.0
# //hw_drivers/lis3mdl:lis3mdl_test                                          1.0
# //:gazelle_python_manifest.test                                            1.0
#
#                                                     group_probability_cache_hit  \
# node_name
# //examples/pigweed/modules/blinky:blinky_test                          0.854411
# //:requirements_test                                                   0.668570
# //examples/basic:grpc_test                                             0.804663
# //examples/basic:hello_test                                            0.875100
# //utils:graph_algorithms_test                                          0.860141
# //third_party/delimited_protobuf:delimited_prot...                     0.897599
# //examples/basic/lib:hello_test                                        0.967482
# //examples/bazel:cat_bin1_pure_test                                    0.983674
# //hw_drivers/lis3mdl:lis3mdl_test                                      0.928412
# //:gazelle_python_manifest.test                                        0.574845
#
#                                                     weighted_source
# node_name
# //examples/pigweed/modules/blinky:blinky_test                32.460
# //:requirements_test                                          5.618
# //examples/basic:grpc_test                                    3.828
# //examples/basic:hello_test                                   2.884
# //utils:graph_algorithms_test                                 2.764
# //third_party/delimited_protobuf:delimited_prot...            2.400
# //examples/basic/lib:hello_test                               0.260
# //examples/bazel:cat_bin1_pure_test                           0.208
# //hw_drivers/lis3mdl:lis3mdl_test                             0.144
# //:gazelle_python_manifest.test                               0.134

# %%
# Find the most impacting source files
df_nodes.loc[df_nodes["node_probability_cache_hit"] < 1].nlargest(
    10, "num_duration_ancestors"
)
# Out:
#                                      node_class  num_parents  num_ancestors  \
# node_name
# //bzl:pytest_main.py                source_file            6              6
# //:pytest.ini                       source_file            4              4
# //examples/basic:hello.proto        source_file            1             61
# //:requirements_lock.txt            source_file            5              6
# //examples/bazel:cat.sh             source_file            1              5
# //examples/bazel:check_equality.sh  source_file            2              2
# //hw_drivers/lis3mdl:lis3mdl.cc     source_file            1             21
# //hw_drivers/lis3mdl:lis3mdl.h      source_file            1             21
# //hw_drivers/lis3mdl:lis3mdl.emb    source_file            1             23
# //hw_drivers/lis3mdl:lis3mdl.proto  source_file            1             44
#
#                                     num_duration_ancestors  num_children  \
# node_name
# //bzl:pytest_main.py                                     4             0
# //:pytest.ini                                            4             0
# //examples/basic:hello.proto                             3             0
# //:requirements_lock.txt                                 2             0
# //examples/bazel:cat.sh                                  2             0
# //examples/bazel:check_equality.sh                       2             0
# //hw_drivers/lis3mdl:lis3mdl.cc                          2             0
# //hw_drivers/lis3mdl:lis3mdl.h                           2             0
# //hw_drivers/lis3mdl:lis3mdl.emb                         2             0
# //hw_drivers/lis3mdl:lis3mdl.proto                       2             0
#
#                                     num_descendants  num_source_descendants  \
# node_name
# //bzl:pytest_main.py                              0                       0
# //:pytest.ini                                     0                       0
# //examples/basic:hello.proto                      0                       0
# //:requirements_lock.txt                          0                       0
# //examples/bazel:cat.sh                           0                       0
# //examples/bazel:check_equality.sh                0                       0
# //hw_drivers/lis3mdl:lis3mdl.cc                   0                       0
# //hw_drivers/lis3mdl:lis3mdl.h                    0                       0
# //hw_drivers/lis3mdl:lis3mdl.emb                  0                       0
# //hw_drivers/lis3mdl:lis3mdl.proto                0                       0
#
#                                     pagerank  hubs_metric  authorities_metric  \
# node_name
# //bzl:pytest_main.py                0.003978          0.0        7.251916e-02
# //:pytest.ini                       0.002048          0.0        6.328747e-02
# //examples/basic:hello.proto        0.017864          0.0       -1.952000e-18
# //:requirements_lock.txt            0.004420          0.0        2.637137e-17
# //examples/bazel:cat.sh             0.002288          0.0       -3.853508e-18
# //examples/bazel:check_equality.sh  0.002182          0.0        2.978338e-19
# //hw_drivers/lis3mdl:lis3mdl.cc     0.001927          0.0        4.895984e-17
# //hw_drivers/lis3mdl:lis3mdl.h      0.001927          0.0        4.198930e-17
# //hw_drivers/lis3mdl:lis3mdl.emb    0.005085          0.0        1.887317e-20
# //hw_drivers/lis3mdl:lis3mdl.proto  0.014708          0.0       -1.108715e-18
#
#                                     node_duration_s  group_duration_s  \
# node_name
# //bzl:pytest_main.py                            0.0             2.530
# //:pytest.ini                                   0.0             2.530
# //examples/basic:hello.proto                    0.0             1.839
# //:requirements_lock.txt                        0.0             2.876
# //examples/bazel:cat.sh                         0.0             0.150
# //examples/bazel:check_equality.sh              0.0             0.150
# //hw_drivers/lis3mdl:lis3mdl.cc                 0.0             0.050
# //hw_drivers/lis3mdl:lis3mdl.h                  0.0             0.050
# //hw_drivers/lis3mdl:lis3mdl.emb                0.0             0.050
# //hw_drivers/lis3mdl:lis3mdl.proto              0.0             0.050
#
#                                     expected_duration_s  \
# node_name
# //bzl:pytest_main.py                           0.082951
# //:pytest.ini                                  0.062213
# //examples/basic:hello.proto                   0.060295
# //:requirements_lock.txt                       0.683639
# //examples/bazel:cat.sh                        0.001230
# //examples/bazel:check_equality.sh             0.001230
# //hw_drivers/lis3mdl:lis3mdl.cc                0.000820
# //hw_drivers/lis3mdl:lis3mdl.h                 0.000820
# //hw_drivers/lis3mdl:lis3mdl.emb               0.000410
# //hw_drivers/lis3mdl:lis3mdl.proto             0.000410
#
#                                     node_probability_cache_hit  \
# node_name
# //bzl:pytest_main.py                                  0.967213
# //:pytest.ini                                         0.975410
# //examples/basic:hello.proto                          0.967213
# //:requirements_lock.txt                              0.762295
# //examples/bazel:cat.sh                               0.991803
# //examples/bazel:check_equality.sh                    0.991803
# //hw_drivers/lis3mdl:lis3mdl.cc                       0.983607
# //hw_drivers/lis3mdl:lis3mdl.h                        0.983607
# //hw_drivers/lis3mdl:lis3mdl.emb                      0.991803
# //hw_drivers/lis3mdl:lis3mdl.proto                    0.991803
#
#                                     group_probability_cache_hit  \
# node_name
# //bzl:pytest_main.py                                   0.967213
# //:pytest.ini                                          0.975410
# //examples/basic:hello.proto                           0.967213
# //:requirements_lock.txt                               0.762295
# //examples/bazel:cat.sh                                0.991803
# //examples/bazel:check_equality.sh                     0.991803
# //hw_drivers/lis3mdl:lis3mdl.cc                        0.983607
# //hw_drivers/lis3mdl:lis3mdl.h                         0.983607
# //hw_drivers/lis3mdl:lis3mdl.emb                       0.991803
# //hw_drivers/lis3mdl:lis3mdl.proto                     0.991803
#
#                                     weighted_source
# node_name
# //bzl:pytest_main.py                            0.0
# //:pytest.ini                                   0.0
# //examples/basic:hello.proto                    0.0
# //:requirements_lock.txt                        0.0
# //examples/bazel:cat.sh                         0.0
# //examples/bazel:check_equality.sh              0.0
# //hw_drivers/lis3mdl:lis3mdl.cc                 0.0
# //hw_drivers/lis3mdl:lis3mdl.h                  0.0
# //hw_drivers/lis3mdl:lis3mdl.emb                0.0
# //hw_drivers/lis3mdl:lis3mdl.proto              0.0

# %%
networkx.ancestors(g, "//hw_drivers/lis3mdl:lis3mdl.proto")
# Out:
# {'//apps/sbr/system:rp2_system',
#  '//apps/sbr:flash_rp2040',
#  '//apps/sbr:flash_rp2350',
#  '//apps/sbr:rp2040_console',
#  '//apps/sbr:rp2040_sbr.elf',
#  '//apps/sbr:rp2350_sbr.elf',
#  '//apps/sbr:sbr',
#  '//apps/sbr:sbr.dwp',
#  '//apps/sbr:sbr.stripped',
#  '//apps/sbr:simulator_console',
#  '//apps/sbr:simulator_sbr',
#  '//apps/sbr:simulator_webconsole',
#  '//examples/pigweed/apps/blinky:simulator_console',
#  '//examples/pigweed/apps/blinky:simulator_webconsole',
#  '//hw_drivers/lis3mdl:lis3mdl',
#  '//hw_drivers/lis3mdl:lis3mdl.pb.cc',
#  '//hw_drivers/lis3mdl:lis3mdl.pb.h',
#  '//hw_drivers/lis3mdl:lis3mdl_cc_library',
#  '//hw_drivers/lis3mdl:lis3mdl_cpp_compile',
#  '//hw_drivers/lis3mdl:lis3mdl_nanopb',
#  '//hw_drivers/lis3mdl:lis3mdl_nanopb_rpc',
#  '//hw_drivers/lis3mdl:lis3mdl_pb2.py',
#  '//hw_drivers/lis3mdl:lis3mdl_pb2.pyi',
#  '//hw_drivers/lis3mdl:lis3mdl_proto',
#  '//hw_drivers/lis3mdl:lis3mdl_pw_test',
#  '//hw_drivers/lis3mdl:lis3mdl_pw_test.dwp',
#  '//hw_drivers/lis3mdl:lis3mdl_pw_test.lib',
#  '//hw_drivers/lis3mdl:lis3mdl_pw_test.stripped',
#  '//hw_drivers/lis3mdl:lis3mdl_py_library',
#  '//hw_drivers/lis3mdl:lis3mdl_python_compile',
#  '//hw_drivers/lis3mdl:lis3mdl_test',
#  '//hw_drivers/lis3mdl:lis3mdl_test.dwp',
#  '//hw_drivers/lis3mdl:lis3mdl_test.stripped',
#  '//hw_services/sbr:sbr_grpc_py_library',
#  '//hw_services/sbr:sbr_nanopb',
#  '//hw_services/sbr:sbr_nanopb_rpc',
#  '//hw_services/sbr:sbr_pb2.py',
#  '//hw_services/sbr:sbr_pb2.pyi',
#  '//hw_services/sbr:sbr_pb2_grpc.py',
#  '//hw_services/sbr:sbr_proto',
#  '//hw_services/sbr:sbr_py_library',
#  '//hw_services/sbr:sbr_python_compile',
#  '//hw_services/sbr:service',
#  '//third_party/pigweed/tools:console'}

# %%
df_nodes["num_parents"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
def get_subgraph(label: str, graph: networkx.DiGraph) -> networkx.DiGraph:
    return graph.subgraph(
        networkx.ancestors(graph, label)
        | networkx.descendants(g, label)
        | set([label])
    )

# %%
def show_graph(graph: networkx.DiGraph, include_labels: bool = True) -> None:
    if include_labels:
        a = nx_agraph.to_agraph(graph)
        a.layout("dot")
        display(a)
    else:
        networkx.draw(graph, nx_agraph.graphviz_layout(graph, prog="dot"))

# %%
H = get_subgraph("//apps/sbr:simulator_sbr", g)

# %%
show_graph(H, include_labels=False)

# %%
show_graph(H, include_labels=True)
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7216ae5970c0>>

# %%
import numpy as np
import pandas as pd

# %%
df_nodes["num_parents"].mean()
# Out:
# np.float64(1.1775456919060052)

# %%
df_nodes.groupby("node_class").mean().sort_values(
    "num_descendants", ascending=False
)
# Out:
#                               num_parents  num_ancestors  \
# node_class
# native_binary                    0.000000       0.000000
# rp2350_binary                    1.000000       1.000000
# rp2040_binary                    2.000000       2.000000
# host_device_simulator_binary     2.000000       2.000000
# oci_tarball                      0.000000       0.000000
# ...                                   ...            ...
# _write_file                      2.000000       5.500000
# gazelle_binary                   1.000000       2.000000
# modules_mapping                  1.000000       1.000000
# source_file                      1.512195       8.853659
# toolchain_type                   2.000000       2.000000
#
#                               num_duration_ancestors  num_children  \
# node_class
# native_binary                               0.000000         2.125
# rp2350_binary                               0.000000         1.000
# rp2040_binary                               0.000000         1.000
# host_device_simulator_binary                0.000000         1.000
# oci_tarball                                 0.000000         2.000
# ...                                              ...           ...
# _write_file                                 0.000000         0.000
# gazelle_binary                              0.000000         0.000
# modules_mapping                             0.000000         0.000
# source_file                                 0.695122         0.000
# toolchain_type                              0.000000         0.000
#
#                               num_descendants  num_source_descendants  \
# node_class
# native_binary                           35.75                  14.125
# rp2350_binary                           30.00                  14.000
# rp2040_binary                           30.00                  14.000
# host_device_simulator_binary            27.50                  13.500
# oci_tarball                             24.00                   2.000
# ...                                       ...                     ...
# _write_file                              0.00                   0.000
# gazelle_binary                           0.00                   0.000
# modules_mapping                          0.00                   0.000
# source_file                              0.00                   0.000
# toolchain_type                           0.00                   0.000
#
#                               pagerank   hubs_metric  authorities_metric  \
# node_class
# native_binary                 0.001179 -3.245030e-17        1.558007e-18
# rp2350_binary                 0.002182 -6.260822e-18        1.356730e-18
# rp2040_binary                 0.002516 -6.260822e-18       -1.474360e-17
# host_device_simulator_binary  0.001848 -3.159747e-18       -3.114270e-17
# oci_tarball                   0.001179  1.079965e-19        2.020296e-18
# ...                                ...           ...                 ...
# _write_file                   0.003003  0.000000e+00       -1.104929e-19
# gazelle_binary                0.003034  0.000000e+00       -1.919991e-19
# modules_mapping               0.001513  0.000000e+00        3.951233e-18
# source_file                   0.003071  0.000000e+00        3.680263e-03
# toolchain_type                0.002182  0.000000e+00       -1.406174e-18
#
#                               node_duration_s  group_duration_s  \
# node_class
# native_binary                             0.0          0.000000
# rp2350_binary                             0.0          0.000000
# rp2040_binary                             0.0          0.000000
# host_device_simulator_binary              0.0          0.000000
# oci_tarball                               0.0          0.000000
# ...                                       ...               ...
# _write_file                               0.0          0.000000
# gazelle_binary                            0.0          0.000000
# modules_mapping                           0.0          0.000000
# source_file                               0.0          0.623902
# toolchain_type                            0.0          0.000000
#
#                               expected_duration_s  node_probability_cache_hit  \
# node_class
# native_binary                            0.000000                     1.00000
# rp2350_binary                            0.000000                     1.00000
# rp2040_binary                            0.000000                     1.00000
# host_device_simulator_binary             0.000000                     1.00000
# oci_tarball                              0.000000                     1.00000
# ...                                           ...                         ...
# _write_file                              0.000000                     1.00000
# gazelle_binary                           0.000000                     1.00000
# modules_mapping                          0.000000                     1.00000
# source_file                              0.023739                     0.97451
# toolchain_type                           0.000000                     1.00000
#
#                               group_probability_cache_hit  weighted_source
# node_class
# native_binary                                    0.835631              0.0
# rp2350_binary                                    0.854943              0.0
# rp2040_binary                                    0.854943              0.0
# host_device_simulator_binary                     0.833981              0.0
# oci_tarball                                      0.935501              0.0
# ...                                                   ...              ...
# _write_file                                      1.000000              0.0
# gazelle_binary                                   1.000000              0.0
# modules_mapping                                  1.000000              0.0
# source_file                                      0.974510              0.0
# toolchain_type                                   1.000000              0.0
#
# [63 rows x 15 columns]

# %%
df_nodes.groupby("node_class").describe()["num_ancestors"].sort_values(
    ["max", "75%"], ascending=False
)[:10]
# Out:
#                        count       mean        std   min    25%   50%    75%  \
# node_class
# source_file             82.0   8.853659   9.992741   1.0   3.00   4.5  12.75
# proto_library            5.0  30.600000  20.378911  13.0  14.00  23.0  43.00
# proto_compile            7.0  13.428571  16.460631   3.0   5.50   8.0  11.00
# unknown                 50.0   4.500000  10.889519   0.0   0.00   0.0   4.00
# py_library              12.0  11.166667  15.032288   0.0   2.75   5.0   9.25
# cc_library              25.0   7.040000   7.902953   0.0   0.00   3.0  13.00
# emboss_library           1.0  22.000000        NaN  22.0  22.00  22.0  22.00
# _nanopb_proto_library    3.0  14.333333   7.094599   8.0  10.50  13.0  17.50
# cc_emboss_library        1.0  21.000000        NaN  21.0  21.00  21.0  21.00
# determine_main          16.0   4.187500   6.347900   1.0   1.00   1.0   4.25
#
#                         max
# node_class
# source_file            61.0
# proto_library          60.0
# proto_compile          50.0
# unknown                47.0
# py_library             44.0
# cc_library             29.0
# emboss_library         22.0
# _nanopb_proto_library  22.0
# cc_emboss_library      21.0
# determine_main         20.0

# %%
df_nodes.groupby("node_class").describe()["num_duration_ancestors"][
    "mean"
].sort_values(ascending=False)[:40].plot.bar()
# Out:
# <Axes: xlabel='node_class'>

# %%
df_nodes.groupby("node_class").describe()["num_source_descendants"][
    "mean"
].sort_values(ascending=False)[:40].plot.bar()
# Out:
# <Axes: xlabel='node_class'>

# %%
df_nodes.loc[df_nodes["node_class"].str.endswith("_test")].sort_values(
    "num_source_descendants", ascending=False
)["num_source_descendants"].plot.bar(subplots=True)
# Out:
# array([<Axes: title={'center': 'num_source_descendants'}, xlabel='node_name'>],
#       dtype=object)

# %%
df_nodes.loc[df_nodes["node_class"].str.endswith("_test")].sort_values(
    "group_probability_cache_hit", ascending=True
)["group_probability_cache_hit"].plot.bar(subplots=True)
# Out:
# array([<Axes: title={'center': 'group_probability_cache_hit'}, xlabel='node_name'>],
#       dtype=object)

# %%
show_graph(get_subgraph("//examples/basic:grpc_test", g), include_labels=True)
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7216ab52e070>>

# %%
df_nodes.loc[df_nodes["node_class"] == "source_file"]
# Out:
#                                          node_class  num_parents  \
# node_name
# //:requirements_lock.txt                source_file            5
# //:gazelle_python.yaml                  source_file            3
# //:requirements.in                      source_file            2
# //.aspect/bazelrc:bazel7.bazelrc        source_file            1
# //.aspect/bazelrc:ci.bazelrc            source_file            1
# ...                                             ...          ...
# //tools/jupyter:jupyter.py              source_file            2
# //tools/sphinx:sphinx_build_wrapper.py  source_file            2
# //utils:bep_reader.py                   source_file            2
# //utils:graph_algorithms.py             source_file            1
# //utils:graph_algorithms_test.py        source_file            1
#
#                                         num_ancestors  num_duration_ancestors  \
# node_name
# //:requirements_lock.txt                            6                       2
# //:gazelle_python.yaml                              3                       1
# //:requirements.in                                  3                       1
# //.aspect/bazelrc:bazel7.bazelrc                    2                       1
# //.aspect/bazelrc:ci.bazelrc                        2                       1
# ...                                               ...                     ...
# //tools/jupyter:jupyter.py                          2                       0
# //tools/sphinx:sphinx_build_wrapper.py              2                       0
# //utils:bep_reader.py                               4                       0
# //utils:graph_algorithms.py                         4                       1
# //utils:graph_algorithms_test.py                    1                       1
#
#                                         num_children  num_descendants  \
# node_name
# //:requirements_lock.txt                           0                0
# //:gazelle_python.yaml                             0                0
# //:requirements.in                                 0                0
# //.aspect/bazelrc:bazel7.bazelrc                   0                0
# //.aspect/bazelrc:ci.bazelrc                       0                0
# ...                                              ...              ...
# //tools/jupyter:jupyter.py                         0                0
# //tools/sphinx:sphinx_build_wrapper.py             0                0
# //utils:bep_reader.py                              0                0
# //utils:graph_algorithms.py                        0                0
# //utils:graph_algorithms_test.py                   0                0
#
#                                         num_source_descendants  pagerank  \
# node_name
# //:requirements_lock.txt                                     0  0.004420
# //:gazelle_python.yaml                                       0  0.003017
# //:requirements.in                                           0  0.002583
# //.aspect/bazelrc:bazel7.bazelrc                             0  0.002303
# //.aspect/bazelrc:ci.bazelrc                                 0  0.002303
# ...                                                        ...       ...
# //tools/jupyter:jupyter.py                                   0  0.003109
# //tools/sphinx:sphinx_build_wrapper.py                       0  0.003109
# //utils:bep_reader.py                                        0  0.002745
# //utils:graph_algorithms.py                                  0  0.002611
# //utils:graph_algorithms_test.py                             0  0.001430
#
#                                         hubs_metric  authorities_metric  \
# node_name
# //:requirements_lock.txt                        0.0        2.637137e-17
# //:gazelle_python.yaml                          0.0        1.031886e-17
# //:requirements.in                              0.0        1.316903e-17
# //.aspect/bazelrc:bazel7.bazelrc                0.0        6.649048e-19
# //.aspect/bazelrc:ci.bazelrc                    0.0       -1.953524e-19
# ...                                             ...                 ...
# //tools/jupyter:jupyter.py                      0.0       -1.074671e-18
# //tools/sphinx:sphinx_build_wrapper.py          0.0       -1.123197e-18
# //utils:bep_reader.py                           0.0        1.644926e-03
# //utils:graph_algorithms.py                     0.0       -1.363460e-20
# //utils:graph_algorithms_test.py                0.0        1.336722e-02
#
#                                         node_duration_s  group_duration_s  \
# node_name
# //:requirements_lock.txt                            0.0             2.876
# //:gazelle_python.yaml                              0.0             0.067
# //:requirements.in                                  0.0             2.809
# //.aspect/bazelrc:bazel7.bazelrc                    0.0             0.028
# //.aspect/bazelrc:ci.bazelrc                        0.0             0.024
# ...                                                 ...               ...
# //tools/jupyter:jupyter.py                          0.0             0.000
# //tools/sphinx:sphinx_build_wrapper.py              0.0             0.000
# //utils:bep_reader.py                               0.0             0.000
# //utils:graph_algorithms.py                         0.0             0.691
# //utils:graph_algorithms_test.py                    0.0             0.691
#
#                                         expected_duration_s  \
# node_name
# //:requirements_lock.txt                           0.683639
# //:gazelle_python.yaml                             0.016475
# //:requirements.in                                 0.345369
# //.aspect/bazelrc:bazel7.bazelrc                   0.000230
# //.aspect/bazelrc:ci.bazelrc                       0.000197
# ...                                                     ...
# //tools/jupyter:jupyter.py                         0.000000
# //tools/sphinx:sphinx_build_wrapper.py             0.000000
# //utils:bep_reader.py                              0.000000
# //utils:graph_algorithms.py                        0.039648
# //utils:graph_algorithms_test.py                   0.022656
#
#                                         node_probability_cache_hit  \
# node_name
# //:requirements_lock.txt                                  0.762295
# //:gazelle_python.yaml                                    0.754098
# //:requirements.in                                        0.877049
# //.aspect/bazelrc:bazel7.bazelrc                          0.991803
# //.aspect/bazelrc:ci.bazelrc                              0.991803
# ...                                                            ...
# //tools/jupyter:jupyter.py                                0.991803
# //tools/sphinx:sphinx_build_wrapper.py                    0.991803
# //utils:bep_reader.py                                     0.975410
# //utils:graph_algorithms.py                               0.942623
# //utils:graph_algorithms_test.py                          0.967213
#
#                                         group_probability_cache_hit  \
# node_name
# //:requirements_lock.txt                                   0.762295
# //:gazelle_python.yaml                                     0.754098
# //:requirements.in                                         0.877049
# //.aspect/bazelrc:bazel7.bazelrc                           0.991803
# //.aspect/bazelrc:ci.bazelrc                               0.991803
# ...                                                             ...
# //tools/jupyter:jupyter.py                                 0.991803
# //tools/sphinx:sphinx_build_wrapper.py                     0.991803
# //utils:bep_reader.py                                      0.975410
# //utils:graph_algorithms.py                                0.942623
# //utils:graph_algorithms_test.py                           0.967213
#
#                                         weighted_source
# node_name
# //:requirements_lock.txt                            0.0
# //:gazelle_python.yaml                              0.0
# //:requirements.in                                  0.0
# //.aspect/bazelrc:bazel7.bazelrc                    0.0
# //.aspect/bazelrc:ci.bazelrc                        0.0
# ...                                                 ...
# //tools/jupyter:jupyter.py                          0.0
# //tools/sphinx:sphinx_build_wrapper.py              0.0
# //utils:bep_reader.py                               0.0
# //utils:graph_algorithms.py                         0.0
# //utils:graph_algorithms_test.py                    0.0
#
# [82 rows x 16 columns]

# %%
show_graph(get_subgraph("//:requirements_lock.txt", g), include_labels=True)
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7216ab5e2430>>

# %%
show_graph(get_subgraph("//:requirements_test", g), include_labels=True)
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7216ae578a50>>

# %%
df_nodes.loc["//:requirements_test"]
# Out:
# node_class                     pip_compile_test
# num_parents                                   0
# num_ancestors                                 0
# num_duration_ancestors                        0
# num_children                                  3
# num_descendants                               3
# num_source_descendants                        2
# pagerank                               0.001179
# hubs_metric                                 0.0
# authorities_metric                          0.0
# node_duration_s                           2.809
# group_duration_s                          2.809
# expected_duration_s                    0.930986
# node_probability_cache_hit                  1.0
# group_probability_cache_hit             0.66857
# weighted_source                           5.618
# Name: //:requirements_test, dtype: object

# %%
df_nodes.loc["//:requirements_lock.txt"]
# Out:
# node_class                     source_file
# num_parents                              5
# num_ancestors                            6
# num_duration_ancestors                   2
# num_children                             0
# num_descendants                          0
# num_source_descendants                   0
# pagerank                           0.00442
# hubs_metric                            0.0
# authorities_metric                     0.0
# node_duration_s                        0.0
# group_duration_s                     2.876
# expected_duration_s               0.683639
# node_probability_cache_hit        0.762295
# group_probability_cache_hit       0.762295
# weighted_source                        0.0
# Name: //:requirements_lock.txt, dtype: object
